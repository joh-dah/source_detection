# %%
from pathlib import Path
import json
import pandas as pd

path = Path('../reports')

# get folders from path
folders = [x for x in path.iterdir() if x.is_dir()]

# in the folders are multiple json files. 
# Create a dataframe that contains in every row the data from the json files named "synthetic.json".

df = pd.DataFrame()
for folder in folders:
    files = [x for x in folder.iterdir() if x.is_file()]
    for file in files:
        with open(file) as json_file:
            data = json.load(json_file)
            data = {k: v for k, v in data.items() if k in ['metrics', 'data stats']}
            data = pd.json_normalize(data, meta=['metrics', 'data stats'])
            data["model"] = folder.name.split("_")[0]
            df = df.append(data, ignore_index=True)
df
# Out:
#     metrics.avg rank of source  metrics.avg prediction for source  \
# 0                      176.849                              0.505
# 1                      170.046                              0.493
# 2                      162.433                              0.675
# 3                      190.014                              0.038
# 4                      161.072                              0.352
# 5                      170.613                              0.537
# 6                      167.689                              0.717
# 7                      194.122                              0.043
# 8                      165.739                              0.698
# 9                      191.529                              0.028
# 10                     180.559                              0.327
# 11                     169.768                              0.552
# 12                     161.798                              0.342
#
#     metrics.avg prediction over all nodes  \
# 0                                   1.404
# 1                                   1.492
# 2                                   0.294
# 3                                   0.016
# 4                                   1.426
# 5                                   1.468
# 6                                   0.327
# 7                                   0.018
# 8                                   0.341
# 9                                   0.011
# 10                                  1.037
# 11                                  1.491
# 12                                  1.241
#
#     metrics.min prediction over all nodes  \
# 0                                   0.074
# 1                                  -0.011
# 2                                   0.000
# 3                                   0.000
# 4                                  -0.015
# 5                                   0.007
# 6                                   0.000
# 7                                   0.000
# 8                                   0.001
# 9                                   0.000
# 10                                  0.086
# 11                                  0.083
# 12                                  0.004
#
#     metrics.max prediction over all nodes  metrics.avg min matching distance  \
# 0                                   3.160                             21.314
# 1                                   3.307                             21.137
# 2                                   0.909                             29.612
# 3                                   0.130                             78.140
# 4                                   3.510                             28.703
# 5                                   3.023                             17.685
# 6                                   0.909                             36.582
# 7                                   0.113                             78.140
# 8                                   0.916                             37.339
# 9                                   0.112                             78.140
# 10                                  2.828                             36.922
# 11                                  3.164                             16.154
# 12                                  3.124                             27.171
#
#     metrics.avg dist to source  metrics.True positive rate  \
# 0                        3.545                       0.684
# 1                        3.545                       0.717
# 2                        3.545                       0.850
# 3                        3.545                       0.000
# 4                        3.545                       0.846
# 5                        3.545                       0.645
# 6                        3.545                       0.894
# 7                        3.545                       0.000
# 8                        3.545                       0.906
# 9                        3.545                       0.000
# 10                       3.545                       0.887
# 11                       3.545                       0.605
# 12                       3.545                       0.828
#
#     metrics.False positive rate  metrics.avg F1 score  metrics.roc score  \
# 0                         0.218                 0.090              0.841
# 1                         0.218                 0.093              0.849
# 2                         0.294                 0.084              0.858
# 3                         0.000                 0.000              0.832
# 4                         0.286                 0.086              0.858
# 5                         0.185                 0.098              0.843
# 6                         0.351                 0.076              0.854
# 7                         0.000                 0.000              0.829
# 8                         0.356                 0.075              0.848
# 9                         0.000                 0.000              0.831
# 10                        0.353                 0.074              0.835
# 11                        0.169                 0.099              0.848
# 12                        0.273                 0.088              0.856
#
#     data stats.graph stats.avg number of nodes  \
# 0                                      1005.99
# 1                                      1005.99
# 2                                      1005.99
# 3                                      1005.99
# 4                                      1005.99
# 5                                      1005.99
# 6                                      1005.99
# 7                                      1005.99
# 8                                      1005.99
# 9                                      1005.99
# 10                                     1005.99
# 11                                     1005.99
# 12                                     1005.99
#
#     data stats.graph stats.avg centrality  \
# 0                                   0.015
# 1                                   0.015
# 2                                   0.015
# 3                                   0.015
# 4                                   0.015
# 5                                   0.015
# 6                                   0.015
# 7                                   0.015
# 8                                   0.015
# 9                                   0.015
# 10                                  0.015
# 11                                  0.015
# 12                                  0.015
#
#     data stats.infection stats.avg number of sources  \
# 0                                             15.555
# 1                                             15.555
# 2                                             15.555
# 3                                             15.555
# 4                                             15.555
# 5                                             15.555
# 6                                             15.555
# 7                                             15.555
# 8                                             15.555
# 9                                             15.555
# 10                                            15.555
# 11                                            15.555
# 12                                            15.555
#
#     data stats.infection stats.avg portion of infected nodes  \
# 0                                               0.218
# 1                                               0.218
# 2                                               0.218
# 3                                               0.218
# 4                                               0.218
# 5                                               0.218
# 6                                               0.218
# 7                                               0.218
# 8                                               0.218
# 9                                               0.218
# 10                                              0.218
# 11                                              0.218
# 12                                              0.218
#
#     data stats.infection stats.std portion of infected nodes     model
# 0                                               0.033           GCNRUS
# 1                                               0.033           GCNRUS
# 2                                               0.033          GCNSIUS
# 3                                               0.033            GCNSI
# 4                                               0.033         GCNRUSLL
# 5                                               0.033           GCNRUS
# 6                                               0.033          GCNSIUS
# 7                                               0.033            GCNSI
# 8                                               0.033          GCNSIUS
# 9                                               0.033            GCNSI
# 10                                              0.033         GCNRUSLL
# 11                                              0.033           GCNRUS
# 12                                              0.033         GCNRUSLL

# %%
metrics = ["avg min matching distance", "avg F1 score", "avg rank of source", "roc score"]

#normalize the column metrics.avg min matching distance with the column data stats.graph stats.avg number of nodes
df['metrics.avg min matching distance'] = df['metrics.avg min matching distance'] / df['metrics.avg dist to source']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for metric in metrics:
    g = sns.catplot(
        data=df, 
        kind="bar", 
        x="model", 
        y=f"metrics.{metric}", 
        errorbar="sd", 
        palette="dark", 
        alpha=.6, 
        height=6
    )
    g.set_axis_labels("", metric)
    plt.title(f"{metric}")
    plt.show()
